# %% [markdown]
# <a href="https://colab.research.google.com/github/Zander-iac/bte320/blob/main/BTE320Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %%
x=2
